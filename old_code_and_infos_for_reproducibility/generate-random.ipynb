# %%
from random import randrange
for i in range(0,100):
    print(randrange(8, 307, 3))
# Out:
# 20
# 218
# 287
# 98
# 11
# 158
# 116
# 77
# 251
# 80
# 71
# 203
# 224
# 197
# 41
# 161
# 83
# 161
# 281
# 41
# 203
# 17
# 293
# 80
# 38
# 140
# 128
# 167
# 257
# 116
# 107
# 44
# 74
# 293
# 56
# 128
# 161
# 299
# 101
# 287
# 206
# 74
# 260
# 92
# 110
# 284
# 47
# 179
# 203
# 68
# 29
# 170
# 254
# 269
# 77
# 212
# 251
# 218
# 17
# 104
# 92
# 86
# 275
# 50
# 155
# 227
# 245
# 290
# 23
# 140
# 248
# 200
# 11
# 41
# 128
# 128
# 98
# 224
# 299
# 221
# 77
# 179
# 125
# 221
# 128
# 170
# 227
# 65
# 305
# 86
# 203
# 167
# 116
# 110
# 47
# 53
# 53
# 218
# 140
# 170

# %%
import random
random.sample(range(8,307,3), 100)
# Out:
# [89,
#  155,
#  224,
#  236,
#  176,
#  95,
#  221,
#  245,
#  278,
#  140,
#  80,
#  200,
#  248,
#  20,
#  302,
#  215,
#  92,
#  284,
#  104,
#  86,
#  206,
#  239,
#  305,
#  53,
#  197,
#  281,
#  23,
#  173,
#  32,
#  143,
#  65,
#  230,
#  44,
#  242,
#  287,
#  116,
#  107,
#  83,
#  212,
#  293,
#  74,
#  152,
#  50,
#  101,
#  137,
#  146,
#  119,
#  149,
#  158,
#  257,
#  71,
#  254,
#  188,
#  98,
#  296,
#  26,
#  227,
#  122,
#  131,
#  8,
#  17,
#  29,
#  35,
#  185,
#  170,
#  260,
#  68,
#  11,
#  77,
#  38,
#  203,
#  266,
#  233,
#  269,
#  164,
#  263,
#  128,
#  62,
#  194,
#  110,
#  179,
#  290,
#  209,
#  134,
#  161,
#  113,
#  14,
#  299,
#  218,
#  182,
#  41,
#  191,
#  272,
#  47,
#  125,
#  167,
#  275,
#  251,
#  59,
#  56]
