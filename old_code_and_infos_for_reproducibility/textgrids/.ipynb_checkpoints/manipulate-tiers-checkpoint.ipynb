# %%
test = open('id1_part1.TextGrid', 'r')

for i in test:
    print i
# Out:
# File type = "ooTextFile"
#
# Object class = "TextGrid"
#
#
#
# xmin = 0
#
# xmax = 150.824989
#
# tiers? <exists>
#
# size = 3
#
# item []:
#
#     item [1]:
#
#         class = "IntervalTier"
#
#         name = "ORT"
#
#         xmin = 0
#
#         xmax = 150.824989
#
#         intervals: size = 101
#
#         intervals [1]:
#
#             xmin = 0.000000
#
#             xmax = 3.210000
#
#             text = ""
#
#         intervals [2]:
#
#             xmin = 3.210000
#
#             xmax = 3.620000
#
#             text = "piff"
#
#         intervals [3]:
#
#             xmin = 3.620000
#
#             xmax = 6.590000
#
#             text = ""
#
#         intervals [4]:
#
#             xmin = 6.590000
#
#             xmax = 6.970000
#
#             text = "piff"
#
#         intervals [5]:
#
#             xmin = 6.970000
#
#             xmax = 9.820000
#
#             text = ""
#
#         intervals [6]:
#
#             xmin = 9.820000
#
#             xmax = 10.190000
#
# ...

# %%
import tgt

tg = tgt.read_textgrid('id1_part1.TextGrid')

# %%
for line in tg:
    print(line)
# Out:
# IntervalTier(start_time=0.0, end_time=150.824989, name="ORT", objects=[Interval(3.21, 3.62, "piff"), Interval(6.59, 6.97, "piff"), Interval(9.82, 10.19, "piff"), Interval(13.1, 13.45, "piff"), Interval(16.12, 16.49, "paff"), Interval(19.2, 19.56, "piff"), Interval(22.28, 22.7, "paff"), Interval(25.4, 25.8, "piff"), Interval(28.58, 28.96, "piff"), Interval(31.15, 31.56, "paff"), Interval(33.69, 34.06, "paff"), Interval(36.36, 36.73, "piff"), Interval(39.02, 39.43, "piff"), Interval(41.89, 42.33, "piff"), Interval(44.55, 44.96, "piff"), Interval(47.35, 47.79, "piff"), Interval(51.48, 51.93, "paff"), Interval(54.7, 55.13, "paff"), Interval(57.71, 57.96, "paff"), Interval(61.16, 61.57, "piff"), Interval(63.98, 64.43, "paff"), Interval(67.04, 67.44, "piff"), Interval(70.01, 70.43, "paff"), Interval(73.08, 73.49, "piff"), Interval(76.24, 76.68, "paff"), Interval(79.09, 79.5, "paff"), Interval(82.21, 82.6, "piff"), Interval(85.46, 85.87, "piff"), Interval(88.31, 88.73, "piff"), Interval(91.
# ...
